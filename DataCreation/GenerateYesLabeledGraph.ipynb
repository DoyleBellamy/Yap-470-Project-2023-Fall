# %%
import networkx as nx
import random as rand
import numpy as np
import matplotlib.pyplot as plt
from kernighan_lin import kernighan_lin_bisection

# %%
# We can get from timeclock
SEED_OF_RANDOM = 2524
rand.seed(SEED_OF_RANDOM)

# %%
# Half of the number of nodes
# We will use 2 graph to generate yes labeled graph
NUMBER_OF_NODES = 100
nodeList_1 = np.arange(1,NUMBER_OF_NODES+1)
nodeList_2 = np.arange(NUMBER_OF_NODES+1,2*NUMBER_OF_NODES+1)

# %%
def create_connected_graph(node_list):
    # Create an empty graph
    G = nx.Graph()

    # Add nodes from the specific node list
    G.add_nodes_from(node_list)

    # Add edges to connect the nodes and ensure connectivity
    while not nx.is_connected(G):
        # Randomly select two nodes from the graph
        node1 = rand.choice(list(G.nodes()))
        node2 = rand.choice(list(G.nodes()))

        # Add an edge between the selected nodes
        G.add_edge(node1, node2)

    return G

# %%
connected_graph_1 = create_connected_graph(nodeList_1)
print(nx.is_connected(connected_graph_1))

connected_graph_2 = create_connected_graph(nodeList_2)
print(nx.is_connected(connected_graph_1))
# Out:
# True
# True

# %%
# Get one main Graph
RENAME_1 = 'G_1_' 
RENAME_2 = 'G_2_'
G_union = nx.union(connected_graph_1,connected_graph_1,rename=(RENAME_1,RENAME_2))
nx.draw(G_union,with_labels= True, font_weight = 'bold')
plt.show()
print(G_union)
# Out:
# Graph with 200 nodes and 420 edges

# %%
# We are adding edges between 2 connected subgraph

# Threshold will be determined by a formula
# TODO
print(list(G_union.nodes()))
EDGES_BETWEEN_PARTITIONS = 3
for i in range (EDGES_BETWEEN_PARTITIONS):
    node1 = RENAME_1 + str(rand.randint(1,NUMBER_OF_NODES))
    node2 = RENAME_2 + str(rand.randint(1,NUMBER_OF_NODES))
    G_union.add_edge(node1,node2)
# Out:
# ['G_1_1', 'G_1_2', 'G_1_3', 'G_1_4', 'G_1_5', 'G_1_6', 'G_1_7', 'G_1_8', 'G_1_9', 'G_1_10', 'G_1_11', 'G_1_12', 'G_1_13', 'G_1_14', 'G_1_15', 'G_1_16', 'G_1_17', 'G_1_18', 'G_1_19', 'G_1_20', 'G_1_21', 'G_1_22', 'G_1_23', 'G_1_24', 'G_1_25', 'G_1_26', 'G_1_27', 'G_1_28', 'G_1_29', 'G_1_30', 'G_1_31', 'G_1_32', 'G_1_33', 'G_1_34', 'G_1_35', 'G_1_36', 'G_1_37', 'G_1_38', 'G_1_39', 'G_1_40', 'G_1_41', 'G_1_42', 'G_1_43', 'G_1_44', 'G_1_45', 'G_1_46', 'G_1_47', 'G_1_48', 'G_1_49', 'G_1_50', 'G_1_51', 'G_1_52', 'G_1_53', 'G_1_54', 'G_1_55', 'G_1_56', 'G_1_57', 'G_1_58', 'G_1_59', 'G_1_60', 'G_1_61', 'G_1_62', 'G_1_63', 'G_1_64', 'G_1_65', 'G_1_66', 'G_1_67', 'G_1_68', 'G_1_69', 'G_1_70', 'G_1_71', 'G_1_72', 'G_1_73', 'G_1_74', 'G_1_75', 'G_1_76', 'G_1_
G_1_60', 'G_1_61', 'G_1_62', 'G_1_63', 'G_1_64', 'G_1_65', 'G_1_66', 'G_1_67', 'G_1_68', 'G_1_69', 'G_1_70', 'G_1_71', 'G_1_72', 'G_1_73', 'G_1_74', 'G_1_75', 'G_1_76', 'G_1_77', 'G_1_78', 'G_1_79', 'G_1_80', 'G_1_81', 'G_1_82', 'G_1_83', 'G_1_84', 'G_1_85', 'G_1_86', 'G_1_87', 'G_1_88', 'G_1_89', 'G_1_90', 'G_1_91', 'G_1_92', 'G_1_93', 'G_1_94', 'G_1_95', 'G_1_96', 'G_1_97', 'G_1_98', 'G_1_99', 'G_1_100', 'G_2_1', 'G_2_2', 'G_2_3', 'G_2_4', 'G_2_5', 'G_2_6', 'G_2_7', 'G_2_8', 'G_2_9', 'G_2_10', 'G_2_11', 'G_2_12', 'G_2_13', 'G_2_14', 'G_2_15', 'G_2_16', 'G_2_17', 'G_2_18', 'G_2_19', 'G_2_20', 'G_2_21', 'G_2_22', 'G_2_23', 'G_2_24', 'G_2_25', 'G_2_26', 'G_2_27', 'G_2_28', 'G_2_29', 'G_2_30', 'G_2_31', 'G_2_32', 'G_2_33', 'G_2_34', 'G_2_35', 'G_2_36', 'G_2_37', 'G_2_38', 'G_2_39', 'G_2_40', 'G_2_41', 'G_2_42', 'G_2_43', 'G_2_44', 'G_2_45', 'G_2_46', 'G_2_47', 'G_2_48', 'G_2_49', 'G_2_50', 'G_2_51', 'G_2_52', 'G_2_53', 'G_2_54', 'G_2_55', 'G_2_56', 'G_2_57', 'G_2_58', 'G_2_59', 'G_2_60', 'G_2_61', 'G_2_62', 'G_2_63', 'G_2_64', 'G_2_65', 'G_2_66', 'G_2_67', 'G_2_68', 'G_2_69', 'G_2_70', 'G_2_71', 'G_2_72', 'G_2_73', 'G_2_74', 'G_2_75', 'G_2_76', 'G_2_77', 'G_2_78', 'G_2_79', 'G_2_80', 'G_2_81', 'G_2_82', 'G_2_83', 'G_2_84', 'G_2_85', 'G_2_86', 'G_2_87', 'G_2_88', 'G_2_89', 'G_2_90', 'G_2_91', 'G_2_92', 'G_2_93', 'G_2_94', 'G_2_95', 'G_2_96', 'G_2_97', 'G_2_98', 'G_2_99', 'G_2_100']

# %%
nx.draw(G_union,with_labels= True, font_weight = 'bold')
print(nx.is_connected(G_union))
plt.show()
# Out:
# True

# %%
# Trying the kernighan-lin algorithm
partition = kernighan_lin_bisection(G_union,max_iter = 200)

# %%
G_partition1 = G_union.subgraph(partition[0])
G_partition2 = G_union.subgraph(partition[1])

# %%
total_edges = G_union.number_of_edges()
partition_1_edges = G_partition1.number_of_edges()
partition_2_edges = G_partition2.number_of_edges()
print("Mincut (# of Edges between graphs) : "+str(total_edges-partition_1_edges-partition_2_edges))


print(nx.is_connected(G_partition1))
print(nx.is_connected(G_partition2))
# Out:
# Mincut (# of Edges between graphs) : 3
# True
# True

# %%
So we get our "yes" labeled graphs by this way 
Parameters can be changed
Whole process will be implemented in .py file and will be automated
